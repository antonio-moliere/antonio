# %% [markdown]
# <a href="https://colab.research.google.com/github/antonio-moliere/Digitalizacion/blob/main/modulo_argumento_Complejos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Cálculo del módulo y argumento de un número Complejo**
#
#
# > Para el caso de un número Complejo $z = a + bi$
# componente Real $\color{red}a$ y componente Imaginaria $\color{red}{bi}$
#
# >El módulo es:  $|z| = \sqrt{a^2 + b^2}$
# y el argumento: $arctan\left({\frac{a}{b}}\right)$
#
# > Hay que recordar que el resultado nos sale en Radianes (R en la calculadora). Tenemos que hacer los ajustes para pasar el valor a grados sexagesimales (D en la calculadora)
#
# En este ejercicio trabajaremos con la biblioteca 'math'. Para ello tenemos dos opciones:
#
#
# ```
# # import math
# al llamar a la función atan, deberemos escribir math.atan(a/b)
# ```
# o
#
# ```
# # from math import arctan
# al llamar a la función arctan, deberemos escribir atan(a/b)
# ```
# **Preferentemente usaremos la opción 'import math'**

# %%
#Empieza por importar la librería math en tu código


#Pedimos los valores de la parte Real(a) e Imaginaria(b) de tu número Complejo


#El argumento lo devuelve en radianes, así que para pasar a sexagesimales usaremos math.degrees
