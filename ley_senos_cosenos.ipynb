# %% [markdown]
# <a href="https://colab.research.google.com/github/antonio-moliere/Digitalizacion/blob/main/ley_senos_cosenos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Ley de Senos y Cosenos**
#
# Dado el siguiente triángulo:
#
# ![ley_senos.png](data:image/png;base64,...)
#
# Podemos encontrarnos con los cuatro situaciones siguientes:
#
# ![ley_seno_coseno.png](data:image/png;base64,...)
#
# Donde los Casos **a** y **b** se resuelven por la Ley de Senos y los casos **c** y **d** por la Ley de Cosenos
#
# ---
# **Ley de Senos**
#
# > $\frac{SenA}{a} = \frac{SenB}{b} = \frac{SenC}{c} $ o
#
# > $\frac{a}{SenA} = \frac{b}{SenB} = \frac{c}{SenC} $
#
# **Ley de Cosenos**
#
# > $a^2 = b^2 + c^2 - 2bcCosA $
#
# > $b^2 = a^2 + c^2 - 2acCosB $
#
# > $c^2 = a^2 + b^2 - 2abCosC $
#
#
# ---
# Escribe debajo el código en Python, para que primero, me de a elegir si usar la Ley de Senos o la de Cosenos y luego que me pida los datos (float), haga los cálculos necesarios y de una respuesta clara.
# ---
